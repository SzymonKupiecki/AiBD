# %% [markdown]
# # Realizacja zadań 3, 4 z lab 1
# ## Szymon Kupiecki, 406746

# %%
from matplotlib import pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# Zad 3

# %%
def f(x):
    return x*x + 5

def print_f(range, title, xlabel, ylabel, legend):
    plt.plot(range, f(range))
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.grid(True)
    plt.legend(legend)
    plt.show()

print_f(np.linspace(-1,1), "<-1,1>", "x", "y", ["function"])
print_f(np.linspace(-6,6), "<-6,6>", "x", "y", ["function"])
print_f(np.linspace(0,5), "<0,5>", "x", "y", ["function"])

# %% [markdown]
# Zad 4

# %%
data = pd.DataFrame(columns=["Name", "Surname", "Age", "Sex"])  # stworzenie dataframeu bez rekordow

# dodawanie pojedynczego rekordu
data = pd.concat([data, pd.DataFrame({"Name" : ["Mariusz"], "Surname" : ["Pudzianowski"], "Age" : [45], "Sex" : ["M"]})], ignore_index=True)

# dodawanie kilku rekordow
rest_of_data = pd.DataFrame({
    "Name" : ["Adam", "Karol", "Adam", "Maria"],
    "Surname" : ["Malysz", "Wojtyla", "Mickiewicz", "Curie-Sklodowska"],
    "Age" : [44, 85, 57, 67],
    "Sex" : ["M", "M", "M", "F"]
})

data = pd.concat([data, rest_of_data], ignore_index=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Name     5 non-null      object
#  1   Surname  5 non-null      object
#  2   Age      5 non-null      object
#  3   Sex      5 non-null      object
# dtypes: object(4)
# memory usage: 288.0+ bytes

# %%
data.describe()
# Out:
#         Name       Surname  Age Sex
# count      5             5    5   5
# unique     4             5    5   2
# top     Adam  Pudzianowski   45   M
# freq       2             1    1   4

# %%
data.head(3)
# Out:
#       Name       Surname Age Sex
# 0  Mariusz  Pudzianowski  45   M
# 1     Adam        Malysz  44   M
# 2    Karol       Wojtyla  85   M
